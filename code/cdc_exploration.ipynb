# %%
import pandas as pd
import numpy as np 
import os 
import altair as alt

# %% [markdown]
# Data courtesy of the CDC's <a href = 'https://www.cdc.gov/ncbddd/disabilityandhealth/dhds/index.html?CDC_AA_refVal=https%3A%2F%2Fwww.cdc.gov%2Fncbddd%2Fdisabilityandhealth%2Fdhds.html'>Disability & Health Data System</a>
#
# Compare by types of disability
# Compare by race & ethncitity

# %%
data = pd.read_csv("preventitive_care.csv")

# %%
data.Stratification1.value_counts()
# Out:
# Any Disability                   459
# Cognitive Disability             459
# Hearing Disability               459
# Mobility Disability              459
# Vision Disability                459
# No Disability                    459
# Self-care Disability             150
# Independent Living Disability    150
# Overall                           40
# Name: Stratification1, dtype: int64

# %%
df = data[(data.Year == 2020.0) & (data.Category == "Prevention & Screenings") & 
          ((data.StratificationCategory1 == 'Any Disability') | (data.Stratification1 == 'No Disability'))]

# %%
d2 = pd.read_csv("preventitive_care_by_race.csv")

# %%
 d2
# Out:
#        Year LocationAbbr                     LocationDesc  \
# 0    2020.0           US  United States, DC & Territories
# 1    2020.0           US  United States, DC & Territories
# 2    2020.0           US  United States, DC & Territories
# 3    2020.0           US  United States, DC & Territories
# 4    2020.0           US  United States, DC & Territories
# ..      ...          ...                              ...
# 615     NaN          NaN                              NaN
# 616     NaN          NaN                              NaN
# 617     NaN          NaN                              NaN
# 618     NaN          NaN                              NaN
# 619     NaN          NaN                              NaN
#
#                                               Question  \
# 0    Binge drinking in the past 30 days among adult...
# 1    Binge drinking in the past 30 days among adult...
# 2    Binge drinking in the past 30 days among adult...
# ...
